# %%
import pandas as pd

# %%
granada = {'Jugador':['Luis Suares','Jorge Molina', 'Antonio Puertas', 'German Sanchez', 'Luis Milla', 'Luis Manuel Arantes Maximiano'],
'Posicion':['Delantero', 'Delantero', 'Centrocampista', 'Defensa', 'Centrocampista', 'Portero'],
'Numero':[9, 23, 10, 6, 5, 1],
'Altura':[185.0, 187.0, 185.0, 187.0, 175.0, 190.0],
'Goles':[7, 7, 5, 2, 2, 0]}

# %%
df = pd.DataFrame(granada, index= granada["Numero"])

# %%
df
# Out:
#                           Jugador        Posicion  Numero  Altura  Goles
# 9                     Luis Suares       Delantero       9   185.0      7
# 23                   Jorge Molina       Delantero      23   187.0      7
# 10                Antonio Puertas  Centrocampista      10   185.0      5
# 6                  German Sanchez         Defensa       6   187.0      2
# 5                      Luis Milla  Centrocampista       5   175.0      2
# 1   Luis Manuel Arantes Maximiano         Portero       1   190.0      0

# %%
df_books = pd.read_csv("bestsellers-with-categories_e591527f-ae45-4fa5-b0d1-d50142128fa6.csv", sep=",", header=0, names=["Nombre","Autor","Radio de Usuario","Vistas", "Precio", "Año", "Genero"])
df_books
# Out:
#                                                 Nombre
# 0                        10-Day Green Smoothie Cleanse  \
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                         Autor  Radio de Usuario  Vistas  Precio   Año
# 0                    JJ Smith               4.7   17350       8  2016  \
# 1                Stephen King               4.6    2052      22  2011
# 2          Jordan B. Peterson               4.7   18979      15  2018
# ...

# %%
df_harry = pd.read_json("harry.json")
df_harry
# Out:
#                       Name                                               Link
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...  \
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
import requests

url = "https://api.xor.cl/red/metro-network"
r = requests.get(url)
metro = r.json()

df_metro = pd.DataFrame(metro)
df_metro
# Out:
#   api_status                 time  issues
# 0         OK  2023-07-24 18:33:20   False  \
# 1         OK  2023-07-24 18:33:20   False
# 2         OK  2023-07-24 18:33:20   False
# 3         OK  2023-07-24 18:33:20   False
# 4         OK  2023-07-24 18:33:20   False
# 5         OK  2023-07-24 18:33:20   False
# 6         OK  2023-07-24 18:33:20   False
#
#                                                lines
# 0  {'name': 'Línea 1', 'id': 'L1', 'issues': Fals...
# 1  {'name': 'Línea 2', 'id': 'L2', 'issues': Fals...
# 2  {'name': 'Línea 3', 'id': 'L3', 'issues': Fals...
# 3  {'name': 'Línea 4', 'id': 'L4', 'issues': Fals...
# 4  {'name': 'Línea 4A', 'id': 'L4A', 'issues': Fa...
# 5  {'name': 'Línea 5', 'id': 'L5', 'issues': Fals...
# 6  {'name': 'Línea 6', 'id': 'L6', 'issues': Fals...

# %%
def df_general(dato):
    general = dato
    general = general.to_json()
    general = pd.read_json(general)
    
    return general



df_lineas = df_metro["lines"]
df_lineas = df_lineas.to_json()
df_lineas = pd.read_json(df_lineas)

df_lineas
# Out:
#                                                                              0
# name                                                                   Línea 1  \
# id                                                                          L1
# issues                                                                   False
# stations_closed_by_schedule                                                  0
# stations                     [{'name': 'San Pablo', 'id': 'san-pablo', 'sta...
#
#                                                                              1
# name                                                                   Línea 2  \
# id                                                                          L2
# issues                                                                   False
# stations_closed_by_schedule                                                  0
# stations                     [{'name': 'La Cisterna', 'id': 'la-cisterna', ...
#
# ...

# %%
df_estaciones = df_lineas[0]
df_estaciones = df_estaciones.to_json()
df_estaciones = pd.read_json(df_estaciones)

linea_1 = df_general(df_estaciones["stations"])
#san_pablo = df_general(linea_1["schedule"])

linea_1
# Out:
#                                                                       0
# name                                                           San Pablo  \
# id                                                             san-pablo
# status                                                                 0
# lines                                                           [L1, L5]
# description                                           Estación Operativa
# is_closed_by_schedule                                              False
# schedule               {'open': {'weekdays': '06:00', 'saturday': '06...
#
#                                                                       1
# name                                                             Neptuno  \
# id                                                               neptuno
# status                                                                 0
# lines                                                               [L1]
# ...

# %%
columna_San_Pablo =
# Out:
#   Cell In[10], line 1
#     columna_San_Pablo =
#                         ^
# SyntaxError: invalid syntax
